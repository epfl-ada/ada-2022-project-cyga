# %%
'''
File name: preprocessing.ipynb
Authors: Yasmin El Euch, Aliénor Bénédicte G Hamoir, Clara Rossignol, Guillaume David E. Ryelandt
Date created: 04/11/2022
Date last modified: 14/12/2022
Python version: 3.8.8
'''
# Out:
# '\nFile name: preprocessing.ipynb\nAuthors: Yasmin El Euch, Aliénor Bénédicte G Hamoir, Clara Rossignol, Guillaume David E. Ryelandt\nDate created: 04/11/2022\nDate last modified: 14/12/2022\nPython version: 3.8.8\n'

# %% [markdown]
# # Oscar_movie2
#
# Test a new dataset

# %% [markdown]
# ---
# ## General Information <a id="GI"> </a>

# %% [markdown]
# The methodology to carry out this investigation will follow the following steps:
#
# - Load the data from Kaggle https://www.kaggle.com/datasets/unanimad/the-oscar-award\
# - Data cleaning and processing\

# %% [markdown]
# ### Folder structure <a id="Folder"> </a>

# %% [markdown]
# ### Imports <a id="Imports"> </a>

# %% [markdown]
# ***Libraries used for milestone 2:***

# %%
#Imports used in this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import t

print('Imports done')
# Out:
# Imports done

# %% [markdown]
# ### Paths <a id="Paths"> </a>

# %% [markdown]
# Required to adapt those path to local file organization

# %%
### PATHs for dataset:
PATH_DATA = 'data/'

#additionnal datasets:
PATH_MOVIE_OSCAR = PATH_DATA+'oscar_nom_win.csv'

# %% [markdown]
# ---
# ##  Preprocess the Data

# %%
#load and read datasets
oscars = pd.read_csv(PATH_MOVIE_OSCAR)
oscars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10395 entries, 0 to 10394
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year_film      10395 non-null  int64
#  1   year_ceremony  10395 non-null  int64
#  2   ceremony       10395 non-null  int64
#  3   category       10395 non-null  object
#  4   name           10395 non-null  object
#  5   film           10091 non-null  object
#  6   winner         10395 non-null  bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 497.5+ KB

# %% [markdown]
# >it is clear that the column film has missing entries. Let us see what is happening

# %%
#print missing values in film column
oscars[oscars['film'].isna()]
# Out:
#        year_film  year_ceremony  ceremony                           category  \
# 16          1927           1928         1                ENGINEERING EFFECTS
# 18          1927           1928         1                ENGINEERING EFFECTS
# 31          1927           1928         1            WRITING (Title Writing)
# 32          1927           1928         1            WRITING (Title Writing)
# 33          1927           1928         1                      SPECIAL AWARD
# ...          ...            ...       ...                                ...
# 10266       2018           2019        91  IRVING G. THALBERG MEMORIAL AWARD
# 10391       2019           2020        92   JEAN HERSHOLT HUMANITARIAN AWARD
# 10392       2019           2020        92                     HONORARY AWARD
# 10393       2019           2020        92                     HONORARY AWARD
# 10394       2019           2020        92                     HONORARY AWARD
#
#                                       name film  winner
# 16                          Ralph Hammeras  NaN   False
# 18                        Nugent Slaughter  NaN   False
# 31                          Joseph Farnham  NaN    True
# 32                      George Marion, Jr.  NaN   False
# 33                            Warner Bros.  NaN    True
# ...                                    ...  ...     ...
# 10266  Kathleen Kennedy and Frank Marshall  NaN    True
# 10391                          Geena Davis  NaN    True
# 10392                          David Lynch  NaN    True
# 10393                            Wes Studi  NaN    True
# 10394                      Lina Wertmüller  NaN    True
#
# [304 rows x 7 columns]

# %%
oscars[oscars['film'].isna()]['category'].unique()
# Out:
# array(['ENGINEERING EFFECTS', 'WRITING (Title Writing)', 'SPECIAL AWARD',
#        'SOUND RECORDING', 'ASSISTANT DIRECTOR',
#        'IRVING G. THALBERG MEMORIAL AWARD',
#        'SPECIAL FOREIGN LANGUAGE FILM AWARD',
#        'HONORARY FOREIGN LANGUAGE FILM AWARD', 'HONORARY AWARD',
#        'JEAN HERSHOLT HUMANITARIAN AWARD', 'SPECIAL ACHIEVEMENT AWARD'],
#       dtype=object)

# %% [markdown]
# As we can see, they are related to honorary awards, or humanitarian causes, https://en.wikipedia.org/wiki/Jean_Hersholt_Humanitarian_Award for example. We are going to discard rows with 'IRVING G. THALBERG MEMORIAL AWARD',
#        'SPECIAL FOREIGN LANGUAGE FILM AWARD',
#        'HONORARY FOREIGN LANGUAGE FILM AWARD', 'HONORARY AWARD',
#        'JEAN HERSHOLT HUMANITARIAN AWARD', 'SPECIAL ACHIEVEMENT AWARD'

# %%
#drop rows with category 'IRVING G. THALBERG MEMORIAL AWARD', 'SPECIAL AWARD', 'HONORARY AWARD','JEAN HERSHOLT HUMANITARIAN AWARD', 'SPECIAL ACHIEVEMENT AWARD'
oscars = oscars[~oscars['category'].isin(['IRVING G. THALBERG MEMORIAL AWARD', 'SPECIAL AWARD', 'HONORARY AWARD','JEAN HERSHOLT HUMANITARIAN AWARD', 'SPECIAL ACHIEVEMENT AWARD'])]
oscars[oscars['film'].isna()]
# Out:
#       year_film  year_ceremony  ceremony  \
# 16         1927           1928         1
# 18         1927           1928         1
# 31         1927           1928         1
# 32         1927           1928         1
# 145        1930           1931         4
# 146        1930           1931         4
# 147        1930           1931         4
# 148        1930           1931         4
# 192        1931           1932         5
# 193        1931           1932         5
# 194        1931           1932         5
# 195        1931           1932         5
# 213        1932           1933         6
# 214        1932           1933         6
# 215        1932           1933         6
# 216        1932           1933         6
# 217        1932           1933         6
# 218        1932           1933         6
# 219        1932           1933         6
# 220        1932           1933         6
# 221        1932           1933         6
# 222        1932           1933         6
# 223        1932           1933         6
# 224        1932           1933         6
# 225        1932           1933         6
# 226        1932           1933         6
# 227        1932           1933         6
# 228        1932           1933         6
# 229        1932           1933         6
# 230        1932           1933         6
# 2278       1948           1949        21
# 2392       1949           1950        22
# 2505       1950           1951        23
# 2624       1951           1952        24
# 2749       1952           1953        25
# 3005       1954           1955        27
# 3133       1955           1956        28
#
#                                   category  \
# 16                     ENGINEERING EFFECTS
# 18                     ENGINEERING EFFECTS
# 31                 WRITING (Title Writing)
# 32                 WRITING (Title Writing)
# 145                        SOUND RECORDING
# 146                        SOUND RECORDING
# 147                        SOUND RECORDING
# 148                        SOUND RECORDING
# 192                        SOUND RECORDING
# 193                        SOUND RECORDING
# 194                        SOUND RECORDING
# 195                        SOUND RECORDING
# 213                     ASSISTANT DIRECTOR
# 214                     ASSISTANT DIRECTOR
# 215                     ASSISTANT DIRECTOR
# 216                     ASSISTANT DIRECTOR
# 217                     ASSISTANT DIRECTOR
# 218                     ASSISTANT DIRECTOR
# 219                     ASSISTANT DIRECTOR
# 220                     ASSISTANT DIRECTOR
# 221                     ASSISTANT DIRECTOR
# 222                     ASSISTANT DIRECTOR
# 223                     ASSISTANT DIRECTOR
# 224                     ASSISTANT DIRECTOR
# 225                     ASSISTANT DIRECTOR
# 226                     ASSISTANT DIRECTOR
# 227                     ASSISTANT DIRECTOR
# 228                     ASSISTANT DIRECTOR
# 229                     ASSISTANT DIRECTOR
# 230                     ASSISTANT DIRECTOR
# 2278   SPECIAL FOREIGN LANGUAGE FILM AWARD
# 2392   SPECIAL FOREIGN LANGUAGE FILM AWARD
# 2505  HONORARY FOREIGN LANGUAGE FILM AWARD
# 2624  HONORARY FOREIGN LANGUAGE FILM AWARD
# 2749  HONORARY FOREIGN LANGUAGE FILM AWARD
# 3005  HONORARY FOREIGN LANGUAGE FILM AWARD
# 3133  HONORARY FOREIGN LANGUAGE FILM AWARD
#
#                                                    name film  winner
# 16                                       Ralph Hammeras  NaN   False
# 18                                     Nugent Slaughter  NaN   False
# 31                                       Joseph Farnham  NaN    True
# 32                                   George Marion, Jr.  NaN   False
# 145   Samuel Goldwyn - United Artists Studio Sound D...  NaN   False
# 146         Metro-Goldwyn-Mayer Studio Sound Department  NaN   False
# 147            Paramount Publix Studio Sound Department  NaN    True
# 148                   RKO Radio Studio Sound Department  NaN   False
# 192         Metro-Goldwyn-Mayer Studio Sound Department  NaN   False
# 193            Paramount Publix Studio Sound Department  NaN    True
# 194                   RKO Radio Studio Sound Department  NaN   False
# 195   Warner Bros.-First National Studio Sound Depar...  NaN   False
# 213                                   Percy Ikerd (Fox)  NaN   False
# 214                                William Tummel (Fox)  NaN    True
# 215                Charles Dorian (Metro-Goldwyn-Mayer)  NaN    True
# 216                    Bunny Dull (Metro-Goldwyn-Mayer)  NaN   False
# 217                John S. Waters (Metro-Goldwyn-Mayer)  NaN   False
# 218                          Charles Barton (Paramount)  NaN    True
# 219                          Sidney S. Brod (Paramount)  NaN   False
# 220                         Arthur Jacobson (Paramount)  NaN   False
# 221                            Eddie Killey (RKO Radio)  NaN   False
# 222                           Dewey Starkey (RKO Radio)  NaN    True
# 223                           Fred Fox (United Artists)  NaN    True
# 224                    Benjamin Silvey (United Artists)  NaN   False
# 225                              Scott Beal (Universal)  NaN    True
# 226                           Joe McDonough (Universal)  NaN   False
# 227                            W. J. Reiter (Universal)  NaN   False
# 228                            Al Alborn (Warner Bros.)  NaN   False
# 229                  Gordon Hollingshead (Warner Bros.)  NaN    True
# 230                        Frank X. Shaw (Warner Bros.)  NaN   False
# 2278   Monsieur Vincent - voted by the Academy Board...  NaN    True
# 2392   The Bicycle Thief - voted by the Academy Boar...  NaN    True
# 2505   The Walls of Malapaga - voted by the Board of...  NaN    True
# 2624   Rashomon - voted by the Board of Governors as...  NaN    True
# 2749  Forbidden Games - Best Foreign Language Film f...  NaN    True
# 3005   Gate of Hell - Best Foreign Language Film fir...  NaN    True
# 3133                                            Samurai  NaN    True

# %% [markdown]
# >the lines with 'film' missing will be difficult to obtain. For example, finding the film for which the assistant director has been nominated will be laborious, indeed, an assistant director may have different movies released in the same year, so it is much more easy to discard them.

# %%
'''categories_to_drop = [('ENGINEERING EFFECTS', oscars['film'].isnull()), 
                     ('WRITING (Title Writing)', oscars['film'].isnull()),
                     ('SOUND RECORDING', oscars['film'].isnull()),
                     ('ASSISTANT DIRECTOR', oscars['film'].isnull()),
                     ('SPECIAL FOREIGN LANGUAGE FILM AWARD', oscars['film'].isnull()),
                     ('HONORARY FOREIGN LANGUAGE FILM AWARD', oscars['film'].isnull())
                    ]

for category, condition in categories_to_drop:
    oscars = oscars.drop(oscars[(oscars['category'] == category) & (condition)].index)'''
#drop rows with missing values in film column
oscars = oscars.drop(oscars[oscars['film'].isnull()].index)
oscars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10091 entries, 0 to 10390
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year_film      10091 non-null  int64
#  1   year_ceremony  10091 non-null  int64
#  2   ceremony       10091 non-null  int64
#  3   category       10091 non-null  object
#  4   name           10091 non-null  object
#  5   film           10091 non-null  object
#  6   winner         10091 non-null  bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 561.7+ KB

# %% [markdown]
# > now the dataset does not contain anymore missing entries. We need to delete rows containing categories which involve prior gender selection (i.e. actor, actress, etc...)

# %%
list(oscars['category'].unique())
# Out:
# ['ACTOR',
#  'ACTRESS',
#  'ART DIRECTION',
#  'CINEMATOGRAPHY',
#  'DIRECTING (Comedy Picture)',
#  'DIRECTING (Dramatic Picture)',
#  'ENGINEERING EFFECTS',
#  'OUTSTANDING PICTURE',
#  'UNIQUE AND ARTISTIC PICTURE',
#  'WRITING (Adaptation)',
#  'WRITING (Original Story)',
#  'WRITING (Title Writing)',
#  'DIRECTING',
#  'WRITING',
#  'OUTSTANDING PRODUCTION',
#  'SOUND RECORDING',
#  'SHORT SUBJECT (Cartoon)',
#  'SHORT SUBJECT (Comedy)',
#  'SHORT SUBJECT (Novelty)',
#  'ASSISTANT DIRECTOR',
#  'FILM EDITING',
#  'MUSIC (Scoring)',
#  'MUSIC (Song)',
#  'DANCE DIRECTION',
#  'WRITING (Screenplay)',
#  'ACTOR IN A SUPPORTING ROLE',
#  'ACTRESS IN A SUPPORTING ROLE',
#  'SHORT SUBJECT (Color)',
#  'SHORT SUBJECT (One-reel)',
#  'SHORT SUBJECT (Two-reel)',
#  'MUSIC (Original Score)',
#  'CINEMATOGRAPHY (Black-and-White)',
#  'CINEMATOGRAPHY (Color)',
#  'SPECIAL EFFECTS',
#  'ART DIRECTION (Black-and-White)',
#  'ART DIRECTION (Color)',
#  'WRITING (Original Screenplay)',
#  'DOCUMENTARY (Short Subject)',
#  'MUSIC (Music Score of a Dramatic Picture)',
#  'MUSIC (Scoring of a Musical Picture)',
#  'OUTSTANDING MOTION PICTURE',
#  'DOCUMENTARY',
#  'MUSIC (Music Score of a Dramatic or Comedy Picture)',
#  'WRITING (Original Motion Picture Story)',
#  'DOCUMENTARY (Feature)',
#  'BEST MOTION PICTURE',
#  'WRITING (Motion Picture Story)',
#  'COSTUME DESIGN (Black-and-White)',
#  'COSTUME DESIGN (Color)',
#  'WRITING (Story and Screenplay)',
#  'FOREIGN LANGUAGE FILM',
#  'WRITING (Screenplay--Adapted)',
#  'WRITING (Screenplay--Original)',
#  'COSTUME DESIGN',
#  'SHORT SUBJECT (Live Action)',
#  'WRITING (Screenplay--based on material from another medium)',
#  'WRITING (Story and Screenplay--written directly for the screen)',
#  'SOUND',
#  'MUSIC (Music Score--substantially original)',
#  'MUSIC (Scoring of Music--adaptation or treatment)',
#  'BEST PICTURE',
#  'SOUND EFFECTS',
#  'SPECIAL VISUAL EFFECTS',
#  'MUSIC (Original Music Score)',
#  'MUSIC (Original Score--for a motion picture [not a musical])',
#  'MUSIC (Score of a Musical Picture--original or adaptation)',
#  'MUSIC (Song--Original for the Picture)',
#  'WRITING (Story and Screenplay--based on material not previously published or produced)',
#  'MUSIC (Original Song Score)',
#  'WRITING (Story and Screenplay--based on factual material or material not previously published or produced)',
#  'MUSIC (Original Dramatic Score)',
#  'MUSIC (Scoring: Adaptation and Original Song Score)',
#  'SHORT SUBJECT (Animated)',
#  'SPECIAL ACHIEVEMENT AWARD (Visual Effects)',
#  'MUSIC (Scoring: Original Song Score and Adaptation -or- Scoring: Adaptation)',
#  'SHORT FILM (Animated)',
#  'SHORT FILM (Live Action)',
#  'WRITING (Screenplay Adapted from Other Material)',
#  'MUSIC (Original Song)',
#  'SPECIAL ACHIEVEMENT AWARD (Sound Effects)',
#  'ACTOR IN A LEADING ROLE',
#  'ACTRESS IN A LEADING ROLE',
#  'MUSIC (Original Song Score and Its Adaptation or Adaptation Score)',
#  'WRITING (Screenplay Written Directly for the Screen--based on factual material or on story material not previously published or produced)',
#  'VISUAL EFFECTS',
#  'SPECIAL ACHIEVEMENT AWARD (Sound Effects Editing)',
#  'MUSIC (Adaptation Score)',
#  'WRITING (Screenplay Based on Material from Another Medium)',
#  'WRITING (Screenplay Written Directly for the Screen)',
#  'MUSIC (Original Song Score and Its Adaptation -or- Adaptation Score)',
#  'SPECIAL ACHIEVEMENT AWARD (Sound Editing)',
#  'SHORT FILM (Dramatic Live Action)',
#  'MAKEUP',
#  'SOUND EFFECTS EDITING',
#  'MUSIC (Original Song Score or Adaptation Score)',
#  'WRITING (Screenplay Based on Material Previously Produced or Published)',
#  'MUSIC (Original Musical or Comedy Score)',
#  'SOUND EDITING',
#  'ANIMATED FEATURE FILM',
#  'WRITING (Adapted Screenplay)',
#  'SOUND MIXING',
#  'MAKEUP AND HAIRSTYLING',
#  'PRODUCTION DESIGN',
#  'INTERNATIONAL FEATURE FILM']

# %% [markdown]
# > we are now interested to merge this dataset which contains the nominees as well as the winner for each year and the other dataset which contains the nominees as well as the sex.
